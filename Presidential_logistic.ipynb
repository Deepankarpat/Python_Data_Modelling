# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('USPresidentialData.csv')
df.head()
# Out:
#    Win/Loss  Optimism  Pessimism  PastUsed  FutureUsed  PresentUsed  \
# 0         1  0.104505   0.050450  0.438144    0.494845     0.067010
# 1         1  0.114575   0.059236  0.291262    0.621359     0.087379
# 2         1  0.112572   0.049302  0.415966    0.516807     0.067227
# 3         1  0.107234   0.046320  0.463492    0.466667     0.069841
# 4         1  0.105826   0.051724  0.334262    0.582173     0.083565
#
#    OwnPartyCount  OppPartyCount  NumericContent  Extra  Emoti  Agree  Consc  \
# 0              2              2        0.001878  4.041  4.049  3.469  2.450
# 1              1              4        0.001419  3.446  3.633  3.528  2.402
# 2              1              1        0.002131  3.463  4.039  3.284  2.159
# 3              1              3        0.001872  4.195  4.661  4.007  2.801
# 4              3              4        0.002229  4.658  4.023  3.283  2.415
#
#    Openn
# 0  2.548
# 1  2.831
# 2  2.465
# 3  3.067
# 4  2.836

# %%
df.shape
# Out:
# (1524, 14)

# %%
win= df[df['Win/Loss']==1]
win.shape
# Out:
# (929, 14)

# %%
loss =df[df['Win/Loss']==0]
loss.shape
# Out:
# (595, 14)

# %%
df.describe()
# Out:
#           Win/Loss     Optimism    Pessimism     PastUsed   FutureUsed  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean      0.609580     0.120886     0.060122     0.383382     0.429553
# std       0.488005     0.035670     0.024912     0.129032     0.131740
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.096524     0.044479     0.300000     0.347675
# 50%       1.000000     0.115848     0.058477     0.366667     0.435679
# 75%       1.000000     0.141884     0.074248     0.449430     0.516263
# max       1.000000     0.271318     0.157303     1.000000     1.000000
#
#        PresentUsed  OwnPartyCount  OppPartyCount  NumericContent        Extra  \
# count  1524.000000    1524.000000    1524.000000     1524.000000  1524.000000
# mean      0.187065       3.301837       3.373360        0.002133     3.676273
# std       0.099578      10.503639       4.909995        0.001635     1.051659
# ...

# %%
df.groupby('Win/Loss').mean()
# Out:
#           Optimism  Pessimism  PastUsed  FutureUsed  PresentUsed  \
# Win/Loss
# 0         0.125341   0.069926  0.385647    0.406989     0.207364
# 1         0.118032   0.053842  0.381931    0.444004     0.174064
#
#           OwnPartyCount  OppPartyCount  NumericContent     Extra     Emoti  \
# Win/Loss
# 0              3.307563       3.157983        0.001600  3.900449  3.168345
# 1              3.298170       3.511302        0.002474  3.532694  3.211105
#
#              Agree     Consc     Openn
# Win/Loss
# 0         3.748617  3.734408  3.719418
# 1         3.637478  3.420165  3.724483

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(df.corr(), annot=True)

# %%
df.isnull().count()
# Out:
# Win/Loss          1524
# Optimism          1524
# Pessimism         1524
# PastUsed          1524
# FutureUsed        1524
# PresentUsed       1524
# OwnPartyCount     1524
# OppPartyCount     1524
# NumericContent    1524
# Extra             1524
# Emoti             1524
# Agree             1524
# Consc             1524
# Openn             1524
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x='Win/Loss',data=df)

# %%
df
# Out:
#       Win/Loss  Optimism  Pessimism  PastUsed  FutureUsed  PresentUsed  \
# 0            1  0.104505   0.050450  0.438144    0.494845     0.067010
# 1            1  0.114575   0.059236  0.291262    0.621359     0.087379
# 2            1  0.112572   0.049302  0.415966    0.516807     0.067227
# 3            1  0.107234   0.046320  0.463492    0.466667     0.069841
# 4            1  0.105826   0.051724  0.334262    0.582173     0.083565
# 5            1  0.075862   0.034483  0.280000    0.520000     0.200000
# 6            1  0.098383   0.064016  0.324074    0.601852     0.074074
# 7            1  0.103779   0.056389  0.369272    0.549865     0.080863
# 8            1  0.106107   0.046885  0.363354    0.537267     0.099379
# 9            1  0.100661   0.059515  0.355482    0.538206     0.106312
# 10           1  0.083261   0.056375  0.379592    0.530612     0.089796
# 11           1  0.098881   0.049627  0.239067    0.660350     0.100583
# ...

# %%
df.columns
# Out:
# Index(['Win/Loss', 'Optimism', 'Pessimism', 'PastUsed', 'FutureUsed',
#        'PresentUsed', 'OwnPartyCount', 'OppPartyCount', 'NumericContent',
#        'Extra', 'Emoti', 'Agree', 'Consc', 'Openn'],
#       dtype='object')

# %%
y= df['Win/Loss']

# %%
X=df.drop('Win/Loss',axis=1,inplace=True)

# %%
df
# Out:
#       Optimism  Pessimism  PastUsed  FutureUsed  PresentUsed  OwnPartyCount  \
# 0     0.104505   0.050450  0.438144    0.494845     0.067010              2
# 1     0.114575   0.059236  0.291262    0.621359     0.087379              1
# 2     0.112572   0.049302  0.415966    0.516807     0.067227              1
# 3     0.107234   0.046320  0.463492    0.466667     0.069841              1
# 4     0.105826   0.051724  0.334262    0.582173     0.083565              3
# 5     0.075862   0.034483  0.280000    0.520000     0.200000              0
# 6     0.098383   0.064016  0.324074    0.601852     0.074074              6
# 7     0.103779   0.056389  0.369272    0.549865     0.080863              2
# 8     0.106107   0.046885  0.363354    0.537267     0.099379              2
# 9     0.100661   0.059515  0.355482    0.538206     0.106312              1
# 10    0.083261   0.056375  0.379592    0.530612     0.089796              1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(df,y,train_size=0.7)
# Out:
# C:\Users\Deepankar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions=logmodel.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
accuracy=confusion_matrix(y_test,predictions)

# %%
accuracy
# Out:
# array([[ 91,  81],
#        [ 57, 229]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.6986899563318777

# %%
logmodel.score(x_test,y_test)
# Out:
# 0.6986899563318777
